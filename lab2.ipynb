# %% [markdown]
# <a href="https://colab.research.google.com/github/ViktoriaZaremba/DataScienceCourseKNU/blob/main/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Лабораторна робота №2**

# %% [markdown]
# 1. Створить вектор v із 100 елементів командою v <- rnorm(100). Для цього вектору виведіть: 10-й елемент; елементи з 10-го по 20-й включно; 10 елементів починаючи з 20-го; елементи більше 0.

# %%
 v <- rnorm(100)
 v
# Out:
#   [1] -1.04429413  1.49542749 -2.34547612 -0.65419327  2.09055457  0.78145044
#   [7] -1.10990549 -1.53722013  1.03485301  0.07125376  1.44215119 -0.63024074
#  [13] -0.56226678  0.43337086  1.30799891 -1.03554466 -1.35673947  0.73417690
#  [19] -0.55195312  1.26559416 -0.48643901 -0.14930944 -0.48046234 -0.45004788
#  [25] -0.24988340  0.13193826 -1.01401763 -0.36774369 -0.20107793  0.97375028
#  [31]  0.91134381 -0.25647381 -0.31866416 -1.11424616  0.16410558  1.27167656
#  [37]  0.05816589  1.28738548 -0.01788604 -0.14150591 -0.95320036  0.88888818
#  [43] -2.08395291 -0.87836807  0.68543105 -0.52910214 -0.91853611  0.68332751
#  [49]  0.77897307 -0.62467320  0.11147498 -1.37847747  0.37238712 -1.13394860
#  [55] -2.49238806  0.78297832  0.71819573  0.29114304  1.55612425  1.21901047
#  [61] -0.49873333 -0.51204175 -0.12961274  0.42003307 -0.24142791  1.84310369
#  [67] -1.05999103 -0.08274184  0.13237898  2.04912457 -0.03513638 -1.05723110
#  [73] -0.98461487 -0.07424632  1.79336553  0.97934932  1.53762002 -0.97224513
#  [79] -0.18620254  0.26286374 -0.48998448  0.94210382  0.75561715  0.80727044
#  [85] -0.91705886  0.37654909  2.02864993 -0.42909526  0.13390831 -1.16633080
#  [91]  0.96011857  1.11608976 -0.03349341  0.63021555 -0.30457651 -0.54720504
#  [97] -0.19139394  0.71405078 -0.34363376 -1.20033747

# %%
cat("\nДесятий елемент: ")
v[10]
cat("\nЕлементи з 10 по 20 включно: ")
v[10:20]
cat("\n10 елементів починаючи з 20-го")
v[20:29]
cat("\nВсі елемерти більше 0")
v[v>0]
# Out:
# Десятий елемент:
# [1] 0.07125376
# Елементи з 10 по 20 включно:
#  [1]  0.07125376  1.44215119 -0.63024074 -0.56226678  0.43337086  1.30799891
#  [7] -1.03554466 -1.35673947  0.73417690 -0.55195312  1.26559416
# 10 елементів починаючи з 20-го
#  [1]  1.2655942 -0.4864390 -0.1493094 -0.4804623 -0.4500479 -0.2498834
#  [7]  0.1319383 -1.0140176 -0.3677437 -0.2010779
# Всі елемерти більше 0
#  [1] 1.49542749 2.09055457 0.78145044 1.03485301 0.07125376 1.44215119
#  [7] 0.43337086 1.30799891 0.73417690 1.26559416 0.13193826 0.97375028
# [13] 0.91134381 0.16410558 1.27167656 0.05816589 1.28738548 0.88888818
# [19] 0.68543105 0.68332751 0.77897307 0.11147498 0.37238712 0.78297832
# [25] 0.71819573 0.29114304 1.55612425 1.21901047 0.42003307 1.84310369
# [31] 0.13237898 2.04912457 1.79336553 0.97934932 1.53762002 0.26286374
# [37] 0.94210382 0.75561715 0.80727044 0.37654909 2.02864993 0.13390831
# [43] 0.96011857 1.11608976 0.63021555 0.71405078

# %% [markdown]
# 2. Створити фрейм (data frame) y командою y <- data.frame(a = rnorm(100), b = 1:100, cc = sample(letters, 100, replace = TRUE)).
# Для цього data frame виведіть:
# * останні 10 строк
# * строки з 10 по 20 включно
# * 10-й елемент стовпця b
# * повністю стовпець cc, при цьому використайте ім’я стовпця

# %%
y <- data.frame(a = rnorm(100), b = 1:100, cc = sample(letters, 100, replace = TRUE))
y
# Out:
#     a            b   cc
# 1   -2.31312096   1  f
# 2   -0.01882802   2  s
# 3   -0.20709604   3  n
# 4   -2.09701520   4  j
# 5   -0.50586107   5  e
# 6   -2.06883011   6  l
# 7    0.17202298   7  x
# 8   -1.21109059   8  i
# 9    1.53875257   9  s
# 10   0.69373171  10  r
# 11  -1.31340428  11  b
# 12  -0.21759892  12  l
# 13  -1.65371081  13  o
# 14  -1.98776199  14  o
# 15  -0.39238117  15  f
# 16   0.86279756  16  j
# 17  -2.24482885  17  i
# 18   0.17122623  18  s
# 19   1.70687670  19  y
# 20  -0.44069063  20  f
# 21  -0.80906487  21  x
# 22   0.63028674  22  g
# 23  -0.36184606  23  e
# 24   1.54952867  24  m
# 25  -0.18813860  25  w
# 26  -0.62188708  26  z
# 27  -0.55639632  27  n
# 28  -1.24560300  28  p
# 29  -0.17530585  29  b
# 30  -0.37178960  30  i
# ⋮   ⋮            ⋮   ⋮
# 71  -0.240160668  71 w
# 72   0.735918738  72 v
# 73  -0.220075318  73 t
# 74  -0.891281106  74 c
# 75  -0.740298526  75 b
# 76   1.879775021  76 r
# 77   0.158357589  77 u
# 78   1.805882650  78 l
# 79   1.666093832  79 y
# 80  -0.985747376  80 a
# 81  -1.466242283  81 r
# 82   0.227270023  82 b
# 83   0.376435115  83 i
# 84   0.285577570  84 z
# 85   0.183067709  85 e
# 86   1.281490811  86 t
# 87  -0.018727387  87 q
# 88  -0.006884392  88 t
# 89   0.508379518  89 k
# 90  -0.592320542  90 l
# 91   1.317611837  91 l
# 92  -1.143579662  92 y
# 93   0.348006732  93 r
# 94  -1.534410025  94 z
# 95  -1.033891824  95 j
# 96  -0.362839112  96 f
# 97   0.876888442  97 u
# 98  -2.186738765  98 x
# 99   0.754081934  99 g
# 100 -0.021500378 100 y

# %% [markdown]
# Для цього data frame виведіть:
# * останні 10 строк

# %%
tail(y, n = 10)
# Out:
#     a           b   cc
# 91   1.31761184  91 l
# 92  -1.14357966  92 y
# 93   0.34800673  93 r
# 94  -1.53441002  94 z
# 95  -1.03389182  95 j
# 96  -0.36283911  96 f
# 97   0.87688844  97 u
# 98  -2.18673876  98 x
# 99   0.75408193  99 g
# 100 -0.02150038 100 y

# %% [markdown]
# Для цього data frame виведіть:
# * строки з 10 по 20 включно

# %%
y[10:20, ]
# Out:
#    a          b  cc
# 10  0.6937317 10 r
# 11 -1.3134043 11 b
# 12 -0.2175989 12 l
# 13 -1.6537108 13 o
# 14 -1.9877620 14 o
# 15 -0.3923812 15 f
# 16  0.8627976 16 j
# 17 -2.2448289 17 i
# 18  0.1712262 18 s
# 19  1.7068767 19 y
# 20 -0.4406906 20 f

# %% [markdown]
# Для цього data frame виведіть:
# * 10-й елемент стовпця b

# %%
y[10,2]
# Out:
# [1] 10

# %% [markdown]
# Для цього data frame виведіть:
# * повністю стовпець cc, при цьому використайте ім’я стовпця

# %%
y[["cc"]]
# Out:
#   [1] "f" "s" "n" "j" "e" "l" "x" "i" "s" "r" "b" "l" "o" "o" "f" "j" "i" "s"
#  [19] "y" "f" "x" "g" "e" "m" "w" "z" "n" "p" "b" "i" "i" "l" "w" "s" "j" "f"
#  [37] "d" "f" "o" "e" "k" "h" "x" "y" "x" "d" "m" "t" "k" "p" "a" "q" "w" "d"
#  [55] "u" "k" "x" "v" "m" "o" "q" "u" "j" "f" "e" "a" "g" "u" "m" "q" "w" "v"
#  [73] "t" "c" "b" "r" "u" "l" "y" "a" "r" "b" "i" "z" "e" "t" "q" "t" "k" "l"
#  [91] "l" "y" "r" "z" "j" "f" "u" "x" "g" "y"

# %%
y$cc
# Out:
#   [1] "f" "s" "n" "j" "e" "l" "x" "i" "s" "r" "b" "l" "o" "o" "f" "j" "i" "s"
#  [19] "y" "f" "x" "g" "e" "m" "w" "z" "n" "p" "b" "i" "i" "l" "w" "s" "j" "f"
#  [37] "d" "f" "o" "e" "k" "h" "x" "y" "x" "d" "m" "t" "k" "p" "a" "q" "w" "d"
#  [55] "u" "k" "x" "v" "m" "o" "q" "u" "j" "f" "e" "a" "g" "u" "m" "q" "w" "v"
#  [73] "t" "c" "b" "r" "u" "l" "y" "a" "r" "b" "i" "z" "e" "t" "q" "t" "k" "l"
#  [91] "l" "y" "r" "z" "j" "f" "u" "x" "g" "y"

# %%
y[3]
# Out:
#     cc
# 1   f
# 2   s
# 3   n
# 4   j
# 5   e
# 6   l
# 7   x
# 8   i
# 9   s
# 10  r
# 11  b
# 12  l
# 13  o
# 14  o
# 15  f
# 16  j
# 17  i
# 18  s
# 19  y
# 20  f
# 21  x
# 22  g
# 23  e
# 24  m
# 25  w
# 26  z
# 27  n
# 28  p
# 29  b
# 30  i
# ⋮   ⋮
# 71  w
# 72  v
# 73  t
# 74  c
# 75  b
# 76  r
# 77  u
# 78  l
# 79  y
# 80  a
# 81  r
# 82  b
# 83  i
# 84  z
# 85  e
# 86  t
# 87  q
# 88  t
# 89  k
# 90  l
# 91  l
# 92  y
# 93  r
# 94  z
# 95  j
# 96  f
# 97  u
# 98  x
# 99  g
# 100 y

# %% [markdown]
# 3. Створити вектор z з елементами 1, 2, 3, NA, 4, NA, 5, NA.
# Для цього вектору:
# * виведіть всі елементи, які не NA;
# * підрахуйте середнє значення всіх елементів цього вектору без NA значень
# * ...та з NA значеннями.

# %%
z = c(1,2,3,NA,4,NA,5,NA)
z
# Out:
# [1]  1  2  3 NA  4 NA  5 NA

# %% [markdown]
# Для цього вектору:
# * виведіть всі елементи, які не NA;

# %%
z[!is.na(z)]
# Out:
# [1] 1 2 3 4 5

# %% [markdown]
# Для цього вектору:
# * підрахуйте середнє значення всіх елементів цього вектору без NA значень

# %%
mean(z,na.rm=TRUE)
# Out:
# [1] 3

# %% [markdown]
# Для цього вектору:
# * підрахуйте середнє значення всіх елементів цього вектору з NA значеннями

# %%
mean(z,na.rm=FALSE)
# Out:
# [1] NA
